# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px
from datetime import datetime

# %%
df=pd.read_csv('NFLX.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
# Plot Netflix Stock Data using matplotlib
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label='Close Price', color='blue', linewidth=2)
plt.title('Netflix Stock Price - Closing Price', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Plot Volume traded using seaborn
plt.figure(figsize=(12,6))
sns.lineplot(x=df.index, y=df['Volume'], color='red')
plt.title('Netflix Stock Trading Volume', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Volume', fontsize=12)
plt.grid(True)
plt.show()

# %%
# Plot the moving average (e.g., 50-day moving average)
df['50_MA'] = df['Close'].rolling(window=50).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label='Close Price', color='blue', linewidth=2)
plt.plot(df['50_MA'], label='50-Day Moving Average', color='orange', linewidth=2)
plt.title('Netflix Stock Price and 50-Day Moving Average', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Plot an interactive candlestick chart using Plotly
fig = px.line(df, x=df.index, y="Close", title="Netflix Stock Price")
fig.update_traces(line_color='blue', name='Close Price')
fig.show()

# %%
# Plot daily percentage change using Plotly
df['Daily Change (%)'] = df['Close'].pct_change() * 100
fig = px.line(df, x=df.index, y='Daily Change (%)', title='Netflix Daily Percentage Change')
fig.update_traces(line_color='green', name='Daily Change (%)')
fig.show()

# %%
# Additional: Plot the correlation matrix using seaborn
correlation_matrix = df[['Open', 'High', 'Low', 'Close', 'Volume']].corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Netflix Stock Data', fontsize=14)
plt.show()
